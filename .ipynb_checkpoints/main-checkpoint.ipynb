# %%
pip install yfinance --upgrade --no-cache-dir
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.55.tar.gz (23 kB)
# Requirement already satisfied, skipping upgrade: pandas>=0.24 in c:\users\kicks\anaconda3\envs\tf\lib\site-packages (from yfinance) (1.1.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in c:\users\kicks\anaconda3\envs\tf\lib\site-packages (from yfinance) (1.18.5)
# Requirement already satisfied, skipping upgrade: requests>=2.20 in c:\users\kicks\anaconda3\envs\tf\lib\site-packages (from yfinance) (2.24.0)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.9.tar.gz (8.1 kB)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.6.1-cp38-cp38-win_amd64.whl (3.5 MB)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\kicks\anaconda3\envs\tf\lib\site-packages (from pandas>=0.24->yfinance) (2020.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in c:\users\kicks\anaconda3\envs\tf\lib\site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\kicks\anaconda3\envs\tf\lib\site-packages (from requests>=2.20->yfinance) (1.25.11)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\kicks\anaconda3\envs\tf\lib\site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\kicks\anaconda3\envs\tf\lib\site-packages (from requests>=2.20->yfinance) (2020.6.20)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\kicks\anaconda3\envs\tf\lib\site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\users\kicks\anaconda3\envs\tf\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Building wheels for collected packages: yfinance, multitasking
#   Building wheel for yfinance (setup.py): started
#   Building wheel for yfinance (setup.py): finished with status 'done'
#   Created wheel for yfinance: filename=yfinance-0.1.55-py2.py3-none-any.whl size=22622 sha256=0c5091a4ab5dd12d8bc7c1d7f257ec99f8eb05dfd623f42db4f1036d3d4e3ff8
#   Stored in directory: C:\Users\kicks\AppData\Local\Temp\pip-ephem-wheel-cache-vhjrkcl0\wheels\b4\c3\39\9c01ae2b4726f37024bba5592bec868b47a2fab5a786e8979a
#   Building wheel for multitasking (setup.py): started
#   Building wheel for multitasking (setup.py): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8372 sha256=6d6991665cc69e9abcd0f4b76163794fa78047e75bd102be76c833ceed6a9a3d
#   Stored in directory: C:\Users\kicks\AppData\Local\Temp\pip-ephem-wheel-cache-vhjrkcl0\wheels\57\6d\a3\a39b839cc75274d2acfb1c58bfead2f726c6577fe8c4723f13
# Successfully built yfinance multitasking
# Installing collected packages: multitasking, lxml, yfinance
# Successfully installed lxml-4.6.1 multitasking-0.0.9 yfinance-0.1.55
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from datetime import date
today  = date.today()
startDate = today.replace(today.year-1)
print(startDate)
print(today)
# Out:
# 2019-11-25
# 2020-11-25

# %%
#[today.replace(today.day+i) for i in range(30)]

# %%
RISKY_ASSET = 'MSFT'
df = yf.download(RISKY_ASSET, start=today.replace(today.year-1),
 end=date.today(), adjusted=True)
adj_close = df['Adj Close']
returns = adj_close.pct_change().dropna()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
RISKY_ASSET = 'MSFT'
START_DATE = '2019-01-01'
END_DATE = '2019-07-31'
df = yf.download(RISKY_ASSET, start=START_DATE,
 end=END_DATE, adjusted=True)
adj_close = df['Adj Close']
returns = adj_close.pct_change().dropna()
print(f'Average return: {100 * returns.mean():.2f}%')
returns.plot(title=f'{RISKY_ASSET} returns: {START_DATE} -{END_DATE}')
adj_close[0]
# Out:
# [*********************100%***********************]  1 of 1 completed
# Average return: 0.24%
# 98.60206604003906

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from datetime import date
from scipy.stats import norm
class MC_GBM_European(object):
    
    def __init__(self):
        # Basic data
        self._ticker = None
        self._end_date = date.today()
        self._start_date = self._end_date.replace(self._end_date.year-1)
        
        # returns 
        self._return = None
        self._adj_close = None
        
        # for GBM and black scholes
        self._So = None
        self._n_sims = None
        self._mu = None
        self._sigma = None
        self._T = None # time to expiration
        self._N = None
        self._gbmpath = None
        self._K = None
        self._r = None
        self._BS_prem = None
        self._MC_BS_prem = None
        
    def set_ticker(self,TICKER):
        self._ticker = TICKER
        
    def set_return(self):
        df = yf.download(self._ticker, start=self._start_date,end=self._end_date, adjusted=True)
        self._adj_close = df['Adj Close']
        self._return = self._adj_close.pct_change().dropna() # log return

    def get_return(self):
        return self._return
    
    def plot_return(self):
        print(f'Average return: {100 * self._return.mean():.2f}%')
        self._return.plot(title=f'{self._ticker} Price until expiration: {self._start_date} - {self._end_date}')
    
    def set_gbm_n_expiration(self,T): # T = time until expiration
        self._So = self._adj_close[-1]
        self._n_sims = 100
        self._mu = self._return.mean()
        self._sigma = self._return.std()
        self._T = T
        self._N = T
        
        
        dt = self._T /self._N
        dW = np.random.normal(scale = np.sqrt(dt),size=(self._n_sims, self._N))
        W = np.cumsum(dW, axis=1)
        time_step = np.linspace(dt, self._T, self._N)
        time_steps = np.broadcast_to(time_step, (self._n_sims, self._N))
        self._gbmpath = self._So * np.exp((self._mu - 0.5 *self._sigma ** 2) * time_steps+ self._sigma * W)
        self._gbmpath  = np.insert(self._gbmpath, 0, self._So, axis=1)
    
    def get_gbm(self):
        return self._gbmpath
    
    def plot_gbm(self):
        PLOT_TITLE = (f'{self._ticker} Simulation 'f'({self._start_date}:{self._end_date})')
        index  = [self._end_date.replace(self._end_date.day+i) for i in range(self._T+1)]
        gbm_simulations_df = pd.DataFrame(np.transpose(self._gbmpath),index=index)
        # plotting
        ax = gbm_simulations_df.plot(alpha=0.2, legend=False)
        line_1, = ax.plot(index, gbm_simulations_df.mean(axis=1),color='red')
        ax.set_title(PLOT_TITLE, fontsize=16)
        
    def set_strike_n_interest(self,strike,interest_rate):
        self._K = strike
        self._r = interest_rate
    # we have S0,K,r,sigma,T, we can compute bs
    def get_BS( self, type='call'):
        d1 = (np.log(self._So/self._K) + (self._r + 0.5 * self._sigma**2) * self._T)/(self._sigma * np.sqrt(self._T))
        d2 = (np.log(self._So/self._K) + (self._r - 0.5 * self._sigma**2) * self._T)/(self._sigma * np.sqrt(self._T))
        if type == 'call':
            val = (self._So*norm.cdf(d1, 0, 1)-self._K*np.exp(-self._r*self._T)*norm.cdf(d2, 0, 1))
        elif type == 'put':
            val = (self._K*np.exp(-self._r*self._T)*norm.cdf(-d2, 0, 1)-self._So *norm.cdf(-d1, 0, 1))
        self._BS_prem = val
        return self._BS_prem
    
    def get_MC_BS(self):
        discount_factor = np.exp(-1 * self._r * self._T)
        self._MC_BS_prem = discount_factor * np.average(np.maximum(0,self._gbmpath[:, -1] - self._K))
        return self._MC_BS_prem

# %%
#When i simulate i get mu and sigma from mean and std of log return 1 year
# I use this to simulate GBM and then Monte carlo price
# Can i use the same sigma for Analytical BS?

# %%
msft = MC_GBM_European()
msft.set_ticker('AMZN')
msft.set_return()
msft.set_gbm_n_expiration(4)
msft.set_strike_n_interest(145,0.02)
print(msft.get_BS())
print(msft.get_MC_BS())
# This is analytical BS price
# Out:
# [*********************100%***********************]  1 of 1 completed
# 2984.208188367688
# 2776.0132768096064

# %%
msft.plot_return()
# Out:
# Average return: 0.25%

# %%
msft.plot_gbm()

# %%
def get_option_prem(ticker,time,strike,interest):
    msft = MC_GBM_European()
    msft.set_ticker(ticker)
    msft.set_return()
    msft.set_gbm_n_expiration(time)
    msft.set_strike_n_interest(strike,interest)
    print(msft.get_BS())
    print(msft.get_MC_BS())

# %%
import euroOptions
get_option_prem('MSFT',10,185.00, 0.0001)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 29.384130530607194
# 33.74779892124788

# %%
for i in np.arange(150,245.5,step = 2.5):
    print("Strike: " + str(i))
    get_option_prem('MSFT',21,i, 0.0014)
# Out:
# Strike: 150.0
# [*********************100%***********************]  1 of 1 completed
# 64.43526162591584
# 67.20157760607354
# Strike: 152.5
# [*********************100%***********************]  1 of 1 completed
# 62.013334986324026
# 64.66903763111063
# Strike: 155.0
# [*********************100%***********************]  1 of 1 completed
# 59.59423251377336
# 69.06577875677937
# Strike: 157.5
# [*********************100%***********************]  1 of 1 completed
# 57.17908808599992
# 58.61810678357907
# Strike: 160.0
# [*********************100%***********************]  1 of 1 completed
# 54.76936924148799
# 55.408202591266466
# Strike: 162.5
# [*********************100%***********************]  1 of 1 completed
# 52.366931570999185
# 55.63481906936503
# Strike: 165.0
# [*********************100%***********************]  1 of 1 completed
# 49.97406886168926
# 53.8919068137295
# Strike: 167.5
# [*********************100%***********************]  1 of 1 completed
# 47.593554922138395
# 47.18508860748826
# Strike: 170.0
# [*********************100%***********************]  1 of 1 completed
# 45.228672901082405
# 46.37770593610221
# Strike: 172.5
# [*********************100%***********************]  1 of 1 completed
# 42.88322815358535
# 43.69206274872625
# Strike: 175.0
# [*********************100%***********************]  1 of 1 completed
# 40.561541321206164
# 43.95595356124086
# Strike: 177.5
# [*********************100%***********************]  1 of 1 completed
# 38.26841925169373
# 40.17149662980675
# Strike: 180.0
# [*********************100%***********************]  1 of 1 completed
# 36.00910262341242
# 38.46041677941452
# Strike: 182.5
# [*********************100%***********************]  1 of 1 completed
# 33.78919056153748
# 33.63886216264747
# Strike: 185.0
# [*********************100%***********************]  1 of 1 completed
# 31.614544016598018
# 36.32765574730404
# Strike: 187.5
# [*********************100%***********************]  1 of 1 completed
# 29.491171092598762
# 31.393317178318142
# Strike: 190.0
# [*********************100%***********************]  1 of 1 completed
# 27.425098739444792
# 27.68283999149013
# Strike: 192.5
# [*********************100%***********************]  1 of 1 completed
# 25.422236159938706
# 27.711328538303732
# Strike: 195.0
# [*********************100%***********************]  1 of 1 completed
# 23.488235852057954
# 28.3525307721237
# Strike: 197.5
# [*********************100%***********************]  1 of 1 completed
# 21.628358375187048
# 23.025874866898402
# Strike: 200.0
# [*********************100%***********************]  1 of 1 completed
# 19.847346694520752
# 24.52727118779024
# Strike: 202.5
# [*********************100%***********************]  1 of 1 completed
# 18.149315355867287
# 21.037735718572943
# Strike: 205.0
# [*********************100%***********************]  1 of 1 completed
# 16.537658837210415
# 18.839321662063462
# Strike: 207.5
# [*********************100%***********************]  1 of 1 completed
# 15.014982297538097
# 18.590867010048857
# Strike: 210.0
# [*********************100%***********************]  1 of 1 completed
# 13.583056692168753
# 17.129912883676276
# Strike: 212.5
# [*********************100%***********************]  1 of 1 completed
# 12.242798942732975
# 11.339263197683222
# Strike: 215.0
# [*********************100%***********************]  1 of 1 completed
# 10.994276627359255
# 9.852159432020244
# Strike: 217.5
# [*********************100%***********************]  1 of 1 completed
# 9.8367355667189
# 8.952582883883073
# Strike: 220.0
# [*********************100%***********************]  1 of 1 completed
# 8.768647780260451
# 8.45357646993927
# Strike: 222.5
# [*********************100%***********************]  1 of 1 completed
# 7.7877766095925836
# 7.837863754347593
# Strike: 225.0
# [*********************100%***********************]  1 of 1 completed
# 6.891255367551182
# 8.13656781990294
# Strike: 227.5
# [*********************100%***********************]  1 of 1 completed
# 6.075675668473792
# 7.425424560482502
# Strike: 230.0
# [*********************100%***********************]  1 of 1 completed
# 5.337181608644471
# 6.232315224485496
# Strike: 232.5
# [*********************100%***********************]  1 of 1 completed
# 4.671566165305876
# 5.153791165862915
# Strike: 235.0
# [*********************100%***********************]  1 of 1 completed
# 4.074366530214753
# 4.367513042274567
# Strike: 237.5
# [*********************100%***********************]  1 of 1 completed
# 3.5409555482282045
# 4.015077904956561
# Strike: 240.0
# [*********************100%***********************]  1 of 1 completed
# 3.066626951748262
# 2.962978202994552
# Strike: 242.5
# [*********************100%***********************]  1 of 1 completed
# 2.646672629885032
# 2.898874161233245
# Strike: 245.0
# [*********************100%***********************]  1 of 1 completed
# 2.276450713777159
# 2.6418915413500166

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("database.db")
df = pd.read_sql_query("SELECT * FROM optionmodel", conn)

# %%
mydf = df[df['symbol_id']==1]

# %%
mydf = mydf.sort_values(by=['data_date']).reset_index()
mydf = mydf.drop(['index'],axis =1)

# %%
mydf
# Out:
#              id  symbol_id            data_date  ask_price ask_size  \
# 0             1          1  2018-01-02 00:00:00    2595.20     None
# 1          3700          1  2018-01-02 00:00:00     121.50     None
# 2          3701          1  2018-01-02 00:00:00     114.30     None
# 3          3702          1  2018-01-02 00:00:00     107.30     None
# 4          3703          1  2018-01-02 00:00:00     100.80     None
# ...         ...        ...                  ...        ...      ...
# 616138  2418994          1  2018-10-01 00:00:00    1446.30     None
# 616139  2418995          1  2018-10-01 00:00:00    1421.40     None
# 616140  2418996          1  2018-10-01 00:00:00    1396.60     None
# 616141  2418972          1  2018-10-01 00:00:00    1992.80     None
# 616142  2421239          1  2018-10-01 00:00:00       0.15     None
#
#         bid_price bid_size   delta      expiration_date   gamma  \
# 0         2588.60     None  0.9991  2018-01-19 00:00:00  0.0000
# 1          117.50     None -0.4237  2018-12-21 00:00:00  0.0011
# 2          110.10     None -0.3973  2018-12-21 00:00:00  0.0010
# 3          103.20     None -0.3724  2018-12-21 00:00:00  0.0010
# 4           96.80     None -0.3491  2018-12-21 00:00:00  0.0009
# ...           ...      ...     ...                  ...     ...
# 616138    1444.20     None  0.9980  2018-12-21 00:00:00  0.0000
# 616139    1419.30     None  0.9980  2018-12-21 00:00:00  0.0000
# 616140    1394.50     None  0.9980  2018-12-21 00:00:00  0.0000
# 616141    1990.60     None  0.9980  2018-12-21 00:00:00  0.0000
# 616142       0.05     None  0.0000  2020-12-18 00:00:00  0.0000
#
#         implied_volatility  last_price  open_interest  type   rho  \
# 0                   0.0589     2580.00         3166.0  call  None
# 1                   0.1333      121.50         5680.0   put  None
# 2                   0.1375      114.50         3693.0   put  None
# 3                   0.1416      105.60        12755.0   put  None
# 4                   0.1456      100.05        14859.0   put  None
# ...                    ...         ...            ...   ...   ...
# 616138              0.0877     1302.90           52.0  call  None
# 616139              0.0877     1411.59          119.0  call  None
# 616140              0.0877      389.15            1.0  call  None
# 616141              0.0877     1873.60           48.0  call  None
# 616142              0.2699        0.10         2213.0   put  None
#
#         strike_price  underlying_price       vega  volume
# 0              100.0           2695.79     0.0000       0
# 1             2650.0           2695.79  1024.1474     237
# 2             2625.0           2695.79  1009.4736       8
# 3             2600.0           2695.79   991.2839     407
# 4             2575.0           2695.79   970.2385       7
# ...              ...               ...        ...     ...
# 616138        1475.0           2924.61     0.0000       0
# 616139        1500.0           2924.61     0.0000       0
# 616140        1525.0           2924.61     0.0000       0
# 616141         925.0           2924.61     0.0000       0
# 616142         100.0           2924.61     0.0000       0
#
# [616143 rows x 19 columns]

# %%
from datetime import datetime

spx['Expiration'] = pd.to_datetime(spx.loc[:,"expiration_date"]) - pd.to_datetime(spx.loc[:,"data_date"])
# Out:
# <ipython-input-3-2c430783987f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spx['Expiration'] = pd.to_datetime(spx.loc[:,"expiration_date"]) - pd.to_datetime(spx.loc[:,"data_date"])

# %%
import numpy as np
spx['Expiration'] = (spx['Expiration']/np.timedelta64(1, 'D')).astype(int)
# Out:
# <ipython-input-5-3a4e32096d33>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spx['Expiration'] = (spx['Expiration']/np.timedelta64(1, 'D')).astype(int)

# %%
spx
# Out:
#               id  symbol_id            data_date  ask_price ask_size  \
# 0              1          1  2018-01-02 00:00:00    2595.20     None
# 1              2          1  2018-01-02 00:00:00    2495.40     None
# 2              3          1  2018-01-02 00:00:00    2395.50     None
# 3              4          1  2018-01-02 00:00:00    2295.60     None
# 4              5          1  2018-01-02 00:00:00    2195.60     None
# ...          ...        ...                  ...        ...      ...
# 2176550  2421235          1  2018-10-01 00:00:00       0.45     None
# 2176551  2421236          1  2018-10-01 00:00:00       0.25     None
# 2176552  2421237          1  2018-10-01 00:00:00       0.25     None
# 2176553  2421238          1  2018-10-01 00:00:00       0.20     None
# 2176554  2421239          1  2018-10-01 00:00:00       0.15     None
#
#          bid_price bid_size   delta      expiration_date  gamma  \
# 0          2588.60     None  0.9991  2018-01-19 00:00:00    0.0
# 1          2488.80     None  0.9991  2018-01-19 00:00:00    0.0
# 2          2388.90     None  0.9991  2018-01-19 00:00:00    0.0
# 3          2289.00     None  0.9991  2018-01-19 00:00:00    0.0
# 4          2189.10     None  0.9991  2018-01-19 00:00:00    0.0
# ...            ...      ...     ...                  ...    ...
# 2176550       0.25     None  0.0000  2020-12-18 00:00:00    0.0
# 2176551       0.20     None  0.0000  2020-12-18 00:00:00    0.0
# 2176552       0.15     None  0.0000  2020-12-18 00:00:00    0.0
# 2176553       0.10     None  0.0000  2020-12-18 00:00:00    0.0
# 2176554       0.05     None  0.0000  2020-12-18 00:00:00    0.0
#
#          implied_volatility  last_price  open_interest  type   rho  \
# 0                    0.0589     2580.00         3166.0  call  None
# 1                    0.0589     2441.10           27.0  call  None
# 2                    0.0589     2381.95          187.0  call  None
# 3                    0.0589     2281.60           42.0  call  None
# 4                    0.0589     2180.00          201.0  call  None
# ...                     ...         ...            ...   ...   ...
# 2176550              0.2699        0.30          531.0   put  None
# 2176551              0.2699        0.25          289.0   put  None
# 2176552              0.2699        0.20          394.0   put  None
# 2176553              0.2699        0.10          301.0   put  None
# 2176554              0.2699        0.10         2213.0   put  None
#
#          strike_price  underlying_price    vega  volume  Expiration
# 0               100.0           2695.79  0.0000       0          17
# 1               200.0           2695.79  0.0000       0          17
# 2               300.0           2695.79  0.0000       0          17
# 3               400.0           2695.79  0.0000       0          17
# 4               500.0           2695.79  0.0000       0          17
# ...               ...               ...     ...     ...         ...
# 2176550         500.0           2924.61  0.0303       0         809
# 2176551         400.0           2924.61  0.0019       2         809
# 2176552         300.0           2924.61  0.0000       0         809
# 2176553         200.0           2924.61  0.0000       0         809
# 2176554         100.0           2924.61  0.0000       0         809
#
# [616143 rows x 20 columns]

# %%
call = spx[spx['type']== 'call']
call = call.loc[:,['last_price','strike_price','underlying_price','Expiration','data_date']]
call['Hist volatility'] = call.underlying_price.pct_change()
call = call.iloc[1:,:]
#from US daily trasury rate uses this month rate
call.loc[call['Expiration'] <= 90, 'Interest']  = 0.09
call.loc[(call['Expiration'] > 90) & (call['Expiration'] <= 180), 'Interest'] = 0.11
call.loc[(call['Expiration'] > 180) & (call['Expiration'] <= 365), 'Interest'] = 0.13
call.loc[(call['Expiration'] > 365) & (call['Expiration'] <= 730), 'Interest'] = 0.16
call.loc[(call['Expiration'] > 730) & (call['Expiration'] <= 1096), 'Interest'] = 0.19

# %%
X = call[['strike_price','underlying_price','Expiration','Hist volatility','Interest']].values
y = call['last_price'].values

# %%
put =  spx[spx['type']== 'put']
put = put.loc[:,['last_price','strike_price','underlying_price','Expiration','data_date']]
put['Hist volatility'] = put.underlying_price.pct_change()
put = put.iloc[1:,:]
#put['Year'] = pd.DatetimeIndex(put['data_date']).year
put.to_csv("spxPut.csv",index= False)

# %%
put.underlying_price.pct_change()
# Out:
# 2184247         NaN
# 2184248    0.003225
# 2184249   -0.004030
# 2184250   -0.009923
# 2184251    0.014109
#              ...
# 4056421    0.009395
# 4056422    0.002454
# 4056423    0.011461
# 4056424    0.009641
# 4056425    0.042760
# Name: underlying_price, Length: 504768, dtype: float64
